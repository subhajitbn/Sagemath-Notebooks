# %% [markdown]
# # c10 expressions

# %% [markdown]
# ## The main definition
# $$
# f_n := (q^{n};q^{n})_{\infty}.
# $$

# %%
# %display latex

# %% [markdown]
# ## Import necessary Sagemath library

# %%
from sage.modular.etaproducts import qexp_eta

# %% [markdown]
# ## Define a power series ring over the field of integers

# %%
R.<q> = PowerSeriesRing(ZZ)

# %% [markdown]
# ## Set the highest precision allowed

# %%
precision = 10000

# %% [markdown]
# ## Set the $q$-product for $f_1 := (q;q)_{\infty}$

# %%
f1 = qexp_eta(ZZ[['q']], precision)

# %% [markdown]
# ## Set $f_2, f_4, f_{10}, f_{20}$

# %%
f10 = f1.V(10)

# %%
f2 = f1.V(2)
f4 = f1.V(4)
f5 = f1.V(5)
f20 = f1.V(20)

# %% [markdown]
# ## Set the generating function of the $10$-core partition function

# %%
c10 = (f10^10)/f1

# %% [markdown]
# ## $q$-series expansion for 10-core

# %%
c10_list = c10.list()

# %%
c10_list[:10]
# Out:
# [1, 1, 2, 3, 5, 7, 11, 15, 22, 30]

# %%
c10_125n_74 = [c10_list[125*i + 74] for i in range(0,11)]
c10_125n_74
# Out:
# [14375,
#  396000,
#  2148250,
#  6732000,
#  15407125,
#  30984375,
#  55548750,
#  88704250,
#  138230625,
#  205379125,
#  283080000]

# %%
[term/125 for term in c10_125n_74]
# Out:
# [115,
#  3168,
#  17186,
#  53856,
#  123257,
#  247875,
#  444390,
#  709634,
#  1105845,
#  1643033,
#  2264640]

# %%
125*(115*f1*f2^7*f5^2/f10 +2909*q*f2^8*f5*f10^2/f1^2 -1541*q^2*f2^4*f10^6/f5 +15325*q^2*f1*f2*f5^2*f10^5 +374*q*f1^4*f5^3*f10^2 +76355*q^3*f1^2*f10^10/f5^3 +312500*q^4*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 14375 + 396000*q + 2148250*q^2 + 6732000*q^3 + 15407125*q^4 + 30984375*q^5 + 55548750*q^6 + 88704250*q^7 + 138230625*q^8 + 205379125*q^9 + 283080000*q^10 + O(q^11)

# %%
125*(115*f1*f2^7*f5^2/f10 +3283*q*f2^2*f5^7 +18106*q^2*f2^4*f10^6/f5 +59617*q^3*f1^2*f10^10/f5^3 +312500*q^4*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 14375 + 396000*q + 2148250*q^2 + 6732000*q^3 + 15407125*q^4 + 30984375*q^5 + 55548750*q^6 + 88704250*q^7 + 138230625*q^8 + 205379125*q^9 + 283080000*q^10 + O(q^11)

# %%
#25*(-2*f1*f2^7*f5^2/f10 -5*q*f1^3*f2^3*f10^3 -25*q^2*f1^5*f10^7/(f2*f5^2) -208*f5^15/f10^6 -364*q*f2^2*f5^7 -1248*q^2*f2^4*f10^6/f5 -15*f1^11*f10/f2^3 -95*f1^6*f2^2*f5 +645*f1*f2^7*f5^2/f10 +250*f2^12*f5^3/(f1^4*f10^2) +5*3065*q*f2^10*f5^5/f1^6 +1200*q^2*f2^9*f10^5/f1^5 -208*q*f1*f5^10/(f2*f10) -156*q^2*f1*f2*f5^2*f10^5).O(11)

# %%
#c10_625n_74 = [c10_list[625*i + 74] for i in range(0,11)]
#c10_625n_74

# %%
[term/625 for term in c10_625n_74]
# Out:
# [23,
#  49575,
#  452928,
#  1792295,
#  4672921,
#  9866521,
#  18885289,
#  31672011,
#  49544285,
#  76169647,
#  108421994]

# %%
625*(23*75*q^2*f1*f5^6*f10^2 -23*225*q^3*f1^2*f5*f10^7/f2 +23*f1*f2^6*f5^6/f10^4 +23*200*q^4*f1^3*f10^12/(f2^2*f5^4) -1368*q^2*f2^6*f10^4/f1 +2743*q*f1^2*f2^5*f5*f10 +2909*q^2*f1^4*f2*f10^5/f5 -374*q*f1^3*f2^2*f5^4 -15271*q*f2^10*f5^2/f1^3 +62500*q*f2^15*f5^3/(f1^8*f10)).O(11)
# Out:
# 14375 + 30984375*q + 283080000*q^2 + 1120184375*q^3 + 2920575625*q^4 + 6166575625*q^5 + 11803305625*q^6 + 19795006875*q^7 + 30965178125*q^8 + 47606029375*q^9 + 67763746250*q^10 + O(q^11)

# %%
625*(23*f1^3*f5^12/f10^6 +49644*q*f2*f5^11/f10^3 +452928*q^2*f1*f5^6*f10^2 +391899*q^3*f1^2*f5*f10^7/f2 +1902853*q^3*f1*f2^2*f10^8/f5^2 +7812500*q^4*f10^10/f1 +7812500*q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# 14375 + 30984375*q + 283080000*q^2 + 1120184375*q^3 + 2920575625*q^4 + 6166575625*q^5 + 11803305625*q^6 + 19795006875*q^7 + 30965178125*q^8 + 47606029375*q^9 + 67763746250*q^10 + O(q^11)

# %%
625*(23*f1^3*f5^12/f10^6 +49644*q*f2*f5^11/f10^3 +452928*q^2*f1*f5^6*f10^2 +2294752*q^3*f1^2*f5*f10^7/f2 +9715353*q^4*f10^10/f1 +201088*q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# 14375 + 30984375*q + 283080000*q^2 + 1120184375*q^3 + 2920575625*q^4 + 6166575625*q^5 + 11803305625*q^6 + 19795006875*q^7 + 30965178125*q^8 + 47606029375*q^9 + 67763746250*q^10 + O(q^11)

# %%
(23*f1^3*f5^12/f10^6 +49644*q*f2*f5^11/f10^3 +452928*q^2*f1*f5^6*f10^2 +391899*q^3*f1^2*f5*f10^7/f2 +1902853*q^3*f1*f2^2*f10^8/f5^2 +7812500*q^4*f10^10/f1 +7812500*q^5*f10^15/(f2*f5^5)).O(21)
# Out:
# 23 + 49575*q + 452928*q^2 + 1792295*q^3 + 4672921*q^4 + 9866521*q^5 + 18885289*q^6 + 31672011*q^7 + 49544285*q^8 + 76169647*q^9 + 108421994*q^10 + 148714263*q^11 + 206017126*q^12 + 268611150*q^13 + 343277216*q^14 + 447029253*q^15 + 551878065*q^16 + 673562927*q^17 + 841281325*q^18 + 1003241242*q^19 + 1184428753*q^20 + O(q^21)

# %%
#(5*23*f1^12*f5^3/f2^6 -49644*f1^11*f10/f2^3 -452928*f1^6*f2^2*f5 +391899*(f2^3*f5^12/(f1*f10^5) -2*q*f2^2*f5^7 -4*q^3*f1^2*f10^10/f5^3 -5*q^2*f1*f2*f5^2*f10^5) +1902853*(f2^9*f5^6/(f1^3*f10^3) +q*f2^8*f5*f10^2/f1^2) +5*7812500*(q*f2^10*f5^5/f1^6 +q^8*f2^9*f10^5/f1^5)).O(4)

# %%
(5*23*f1^12*f5^3/f2^6 -49644*f1^11*f10/f2^3 -452928*f1^6*f2^2*f5 +391899*f1*f2^7*f5^2/f10 +1902853*(f2^9*f5^6/(f1^3*f10^3) +q*f2^8*f5*f10^2/f1^2) +5*7812500*(q*f2^10*f5^5/f1^6 +q^2*f2^9*f10^5/f1^5)).O(5)
# Out:
# 1792295 + 49544285*q + 268611150*q^2 + 841281325*q^3 + 1925850190*q^4 + O(q^5)

# %%
(5*23*f1^12*f5^3/f2^6 -49644*f1^11*f10/f2^3 -452928*f1^6*f2^2*f5 +391899*f1*f2^7*f5^2/f10 +1902853*f2^12*f5^3/(f1^4*f10^2) +5*7812500*q*f2^13*f5^2*f10/f1^7).O(11)
# Out:
# 1792295 + 49544285*q + 268611150*q^2 + 841281325*q^3 + 1925850190*q^4 + 3873125575*q^5 + 6943297075*q^6 + 11087917975*q^7 + 17279759025*q^8 + 25672720185*q^9 + 35385202320*q^10 + O(q^11)

# %%
#(f1^11*f10/f2^3 + 2*f1^6*f2^2*f5 -f1*f2^7*f5^2/f10 -2*f2^12*f5^3/(f1^4*f10^2)).O(11)

# %%
#(f1^11*f10/f2^3 -f1*f2^7*f5^2/f10).O(11)

# %%
5*(23*f1^12*f5^3/f2^6 +358436*f1^11*f10/f2^3 +1841824*q*f1^8*f10^4/(f2^2*f5) +2294752*q*f1^3*f2^3*f10^3 +1902853*q*f2^8*f5*f10^2/f1^2 +7812500*q*f2^13*f5^2*f10/f1^7).O(11)
# Out:
# 1792295 + 49544285*q + 268611150*q^2 + 841281325*q^3 + 1925850190*q^4 + 3873125575*q^5 + 6943297075*q^6 + 11087917975*q^7 + 17279759025*q^8 + 25672720185*q^9 + 35385202320*q^10 + O(q^11)

# %%
c10_3125n_1949_gen = 3125*(358459*f1*f2^7*f5^2/f10 +10270191*q*f2^2*f5^7 -2875*q*f1*f5^10/(f2*f10) +56587027*q^2*f2^4*f10^6/f5 +186287434*q^3*f1^2*f10^10/f5^3 +976562500*q^4*f2*f10^13/(f1*f5^4))
c10_3125n_1949_gen.O(11)
# Out:
# 1120184375 + 30965178125*q + 167881968750*q^2 + 525800828125*q^3 + 1203656368750*q^4 + 2420703484375*q^5 + 4339560671875*q^6 + 6929948734375*q^7 + 10799849390625*q^8 + 16045450115625*q^9 + 22115751450000*q^10 + O(q^11)

# %%
c10_3125n_1949 = [c10_list[3125*i + 1949] for i in range(0,20)]
c10_3125n_1949
# Out:
# [1120184375,
#  30965178125,
#  167881968750,
#  525800828125,
#  1203656368750,
#  2420703484375,
#  4339560671875,
#  6929948734375,
#  10799849390625,
#  16045450115625,
#  22115751450000,
#  30676843037500,
#  41486879515625,
#  52811949312500,
#  68587814915625,
#  87513862843750,
#  106030130696875,
#  131640791062500,
#  161663120359375,
#  189571709287500]

# %%
c10_3125n_1949_gen = 3125*(358459* +10270191*q* -2875*q* +56587027*q^2* +186287434*q^3* +976562500*q^4*
c10_3125n_1949_gen.O(11)

# %%
[term/15625 for term in c10_3125n_1949]
# Out:
# [358459/5,
#  9908857/5,
#  10744446,
#  33651253,
#  385170038/5,
#  154925023,
#  277731883,
#  443516719,
#  691190361,
#  5134544037/5,
#  7077040464/5,
#  9816589772/5,
#  2655160289,
#  3379964756,
#  21948100773/5,
#  5600887222,
#  33929641823/5,
#  8425010628,
#  10346439703,
#  60662946972/5]

# %%
c10_3125n_1949 = [c10_list[3125*i + 1949] for i in range(0,20)]
c10_3125n_1949

# %%
c10_15625n_8199 = [c10_list[15625*i + 8199] for i in range(0,6)]
[term/15625 for term in c10_15625n_8199]
# Out:
# [10744446, 443516719, 2655160289, 8425010628, 19961064987, 41120049674]

# %%
c10_15625n_11324 = [c10_list[15625*i + 11324] for i in range(0,6)]
[term/15625 for term in c10_15625n_11324]
# Out:
# [33651253, 691190361, 3379964756, 10346439703, 23508833137, 45473486579]

# %%
(23*f1^12*f5^3/f2^6 +358436*f1^11*f10/f2^3 +1841824*q*f1^8*f10^4/(f2^2*f5) +2294752*q*f1^3*f2^3*f10^3 +1902853*q*f2^8*f5*f10^2/f1^2 +7812500*q*f2^13*f5^2*f10/f1^7).O(11)
# Out:
# 358459 + 9908857*q + 53722230*q^2 + 168256265*q^3 + 385170038*q^4 + 774625115*q^5 + 1388659415*q^6 + 2217583595*q^7 + 3455951805*q^8 + 5134544037*q^9 + 7077040464*q^10 + O(q^11)

# %%
(23*f5^15/f10^6 +358436*f1*f2^7*f5^2/f10 +2576*q*f2^2*f5^7 +10267569*q*f1^3*f2^3*f10^3 -2852*q*f1*f5^10/(f2*f10) -1472*q^2*f1*f2*f5^2*f10^5 +87391045*q^2*f2^4*f10^6/f5 +196553600*q^3*f1^2*f10^10/f5^3 +976562500*q^4*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 358459 + 9908857*q + 53722230*q^2 + 168256265*q^3 + 385170038*q^4 + 774625115*q^5 + 1388659415*q^6 + 2217583595*q^7 + 3455951805*q^8 + 5134544037*q^9 + 7077040464*q^10 + O(q^11)

# %%
(23*f5^15/f10^6 +358436*f1*f2^7*f5^2/f10 +2576*q*f2^2*f5^7 +10267569*q*f1^3*f2^3*f10^3 -2852*q*f1*f5^10/(f2*f10) +87389573*q^2*f2^4*f10^6/f5 +196555072*q^3*f1^2*f10^10/f5^3 +976562500*q^4*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 358459 + 9908857*q + 53722230*q^2 + 168256265*q^3 + 385170038*q^4 + 774625115*q^5 + 1388659415*q^6 + 2217583595*q^7 + 3455951805*q^8 + 5134544037*q^9 + 7077040464*q^10 + O(q^11)

# %%
(358459*f1*f2^7*f5^2/f10 +2530*q*f2^2*f5^7 +10267661*q*f1^3*f2^3*f10^3 -2875*q*f1*f5^10/(f2*f10) +87390033*q^2*f2^4*f10^6/f5 -23*q^2*f1*f2*f5^2*f10^5 +196555072*q^3*f1^2*f10^10/f5^3 +976562500*q^4*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 358459 + 9908857*q + 53722230*q^2 + 168256265*q^3 + 385170038*q^4 + 774625115*q^5 + 1388659415*q^6 + 2217583595*q^7 + 3455951805*q^8 + 5134544037*q^9 + 7077040464*q^10 + O(q^11)

# %%
(358459*f1*f2^7*f5^2/f10 +10270191*q*f2^2*f5^7 -2875*q*f1*f5^10/(f2*f10) +56587027*q^2*f2^4*f10^6/f5 +186287434*q^3*f1^2*f10^10/f5^3 +976562500*q^4*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 358459 + 9908857*q + 53722230*q^2 + 168256265*q^3 + 385170038*q^4 + 774625115*q^5 + 1388659415*q^6 + 2217583595*q^7 + 3455951805*q^8 + 5134544037*q^9 + 7077040464*q^10 + O(q^11)

# %%
#25*(-5*q*f1^3*f2^3*f10^3 -25*q^2*f1^5*f10^7 / (f2*f5^2) + 250*q*f2^2*f5^7 -1290*q^2*f2^4*f10^6 / f5 -1200*f2^14*f5^7 / (f1^8*f10^4) +14125*q*f2^10*f5^5 / f1^6 -15*f1^11*f10 / f2^3 -95*f1^6*f2^2*f5 +250*f2^12*f5^3 / (f1^4*f10^2) +1200*f2^17*f5^4 / (f1^9*f10^3) +643*f1*f2^7*f5^2 / f10 - 208*f5^15 / f10^6).O(10)

# %%
#25*(783*f1*f2^7*f5^2/f10 -208*f5^15/f10^6 +14961*q*f2^2*f5^7 +7672*q^2*f2^4*f10^6/f5 +1870*q*f1^4*f5^3*f10^2 +381775*q^3*f1^2*f10^10/f5^3 +91794*q^2*f1*f2*f5^2*f10^5 +1562500*q^4*f2*f10^13/(f1*f5^4) -208*q*f1*f5^10/(f2*f10)).O(11)

# %%
#(q*f1*f5^10/(f2*f10)).O(5)

# %%
#(q*f2^2*f5^7).O(5)

# %%
#5*(f2^2*f5^7 + 6*q*f1*f2*f5^2*f10^5 + 25*q^2*f5^4*f10^7 / (f1*f2) + 25*q^3*f10^12 / (f2^2*f5)).O(11)

# %%
c10_5n_4 = [c10_list[5*i + 4] for i in range(0,11)]
c10_5n_4
# Out:
# [5, 30, 85, 190, 400, 715, 1135, 1785, 2625, 3600, 5020]

# %%
5*(f2^10*f5^5/f1^6).O(11)
# Out:
# 5 + 30*q + 85*q^2 + 190*q^3 + 400*q^4 + 715*q^5 + 1135*q^6 + 1785*q^7 + 2625*q^8 + 3600*q^9 + 5020*q^10 + O(q^11)

# %%
5*(f2^2*f5^7 +6*q*f2^4*f10^6/f5 +19*q^2*f1^2*f10^10/f5^3 +100*q^3*f2*f10^13/(f1*f5^4)).O(11)
# Out:
# 5 + 30*q + 85*q^2 + 190*q^3 + 400*q^4 + 715*q^5 + 1135*q^6 + 1785*q^7 + 2625*q^8 + 3600*q^9 + 5020*q^10 + O(q^11)

# %%
#5*(-f1^7*f10^2 + 6*f1^2*f2^5*f5*f10 + 25*(3*f2*f5^11/f10^3 + 19*q*f1*f5^6*f10^2 + 129*q^2*f1^2*f5*f10^7/f2 + 488*q^3*f10^10/f1 +48*q^4*f10^15/(f2*f5^5)) + 125*q*(2*f2^6*f10^4/f1 + 25*q^2*f10^10/f1)).O(11)

# %%
c10_25n_24 = [c10_list[25*i + 24] for i in range(0,11)]

# %%
c10_25n_24
# Out:
# [400,
#  3600,
#  14375,
#  37325,
#  79075,
#  150950,
#  253575,
#  396000,
#  609275,
#  867825,
#  1189725]

# %%
25*(f1^3*f2^2*f5^4 +15*f2*f5^11/f10^3 +95*q*f1*f5^6*f10^2 +52*q*f1^4*f2*f10^5/f5 +645*q^2*f1^2*f5*f10^7/f2 +250*q^2*f1*f2^2*f10^8/f5^2 +3065*q^3*f10^10/f1 +240*q^4*f10^15/(f2*f5^5)).O(11)
# Out:
# 400 + 3600*q + 14375*q^2 + 37325*q^3 + 79075*q^4 + 150950*q^5 + 253575*q^6 + 396000*q^7 + 609275*q^8 + 867825*q^9 + 1189725*q^10 + O(q^11)

# %%
c10_25n_24_gen = 25*(16*f2*f5^11/f10^3 +144*q*f1*f5^6*f10^2 +735*q^2*f1^2*f5*f10^7/f2 +3107*q^3*f10^10/f1 +72*q^4*f10^15/(f2*f5^5))
c10_25n_24_gen.O(11)
# Out:
# 400 + 3600*q + 14375*q^2 + 37325*q^3 + 79075*q^4 + 150950*q^5 + 253575*q^6 + 396000*q^7 + 609275*q^8 + 867825*q^9 + 1189725*q^10 + O(q^11)

# %%
#25*(f1^2*f2^5*f5*f10 + q*f1^4*f2*f10^5/f5 + 15*f2*f5^11/f10^3 + 95*q*f1*f5^6*f10^2 + 645*q^2*f1^2*f5*f10^7/f2 + 2440*q^3*f10^10/f1 + 240*q^4*f10^15/(f2*f5^5) + 50*q*f2^6*f10^4/f1 + 625*q^3*f10^10/f1).O(11)

# %%
#(-2*f1^3*f2*f5^8/f10^3 -9*q*f1^4*f5^3*f10^2 -32*q^2*f1^5*f10^7/(f2*f5^2)).O(11)

# %%
#(-2*f1*f2^7*f5^2/f10 -5*q*f1^3*f2^3*f10^3 -25*q^2*f1^5*f10^7/(f2*f5^2)).O(11)

# %%
(-208*f2^6*f5^9/(f1^2*f10^4) -1248*q^2*f2^4*f10^6/f5 -156*q*f2^5*f5^4*f10/f1).O(11)
# Out:
# -208 - 572*q - 1196*q^2 + 884*q^3 + 5512*q^4 + 3120*q^5 + 2340*q^6 - 4264*q^7 - 15340*q^8 + 1508*q^9 - 13468*q^10 + O(q^11)

# %%
(-208*f5^15/f10^6 -208*q*f1*f5^10/(f2*f10) -364*q*f2^2*f5^7 -156*q^2*f1*f2*f5^2*f10^5 -1248*q^2*f2^4*f10^6/f5).O(11)
# Out:
# -208 - 572*q - 1196*q^2 + 884*q^3 + 5512*q^4 + 3120*q^5 + 2340*q^6 - 4264*q^7 - 15340*q^8 + 1508*q^9 - 13468*q^10 + O(q^11)

# %%
(-208*f5^15/f10^6 +250*q*f2^2*f5^7 -1290*q^2*f2^4*f10^6/f5).O(11)
# Out:
# -208 + 250*q - 1290*q^2 - 500*q^3 + 5160*q^4 + 2870*q^5 - 4330*q^6 - 790*q^7 - 6820*q^8 + 5410*q^9 - 11768*q^10 + O(q^11)

# %%
(q^3*f1^2/f2).O(500)
# Out:
# q^3 - 2*q^4 + 2*q^7 - 2*q^12 + 2*q^19 - 2*q^28 + 2*q^39 - 2*q^52 + 2*q^67 - 2*q^84 + 2*q^103 - 2*q^124 + 2*q^147 - 2*q^172 + 2*q^199 - 2*q^228 + 2*q^259 - 2*q^292 + 2*q^327 - 2*q^364 + 2*q^403 - 2*q^444 + 2*q^487 + O(q^500)

# %%
(f5^12/(f1^2*f2^4*f10^5) -2*q*f5^7/(f1*f2^5) -4*q^3*(f1*f10^10)/(f2^7*f5^3) -5*q^2*(f5^2*f10^5)/f2^6) .O(10)
# Out:
# 1 + 2*q^2 + 12*q^4 - 2*q^5 + 54*q^6 - 4*q^7 + 196*q^8 - 24*q^9 + O(q^10)

# %%
(1/f1*f2).O(50)
# Out:
# 1 + q + q^2 + 2*q^3 + 2*q^4 + 3*q^5 + 4*q^6 + 5*q^7 + 6*q^8 + 8*q^9 + 10*q^10 + 12*q^11 + 15*q^12 + 18*q^13 + 22*q^14 + 27*q^15 + 32*q^16 + 38*q^17 + 46*q^18 + 54*q^19 + 64*q^20 + 76*q^21 + 89*q^22 + 104*q^23 + 122*q^24 + 142*q^25 + 165*q^26 + 192*q^27 + 222*q^28 + 256*q^29 + 296*q^30 + 340*q^31 + 390*q^32 + 448*q^33 + 512*q^34 + 585*q^35 + 668*q^36 + 760*q^37 + 864*q^38 + 982*q^39 + 1113*q^40 + 1260*q^41 + 1426*q^42 + 1610*q^43 + 1816*q^44 + 2048*q^45 + 2304*q^46 + 2590*q^47 + 2910*q^48 + 3264*q^49 + O(q^50)

# %% [markdown]
# ## Verifications 14.11.2023

# %% [markdown]
# ### 1

# %%
c10_15625n_1949 = [c10_list[15625*i + 1949] for i in range(0,7)]

# %%
[term/3125 for term in c10_15625n_1949]
# Out:
# [358459,
#  774625115,
#  7077040464,
#  28004436110,
#  73014343873,
#  154165098863,
#  295081997657]

# %%
#T1 = 358459*(f1^3*f5^12/f10^6 -12*q*f2*f5^11/f10^3 +96*q^2*f1*f5^6*f10^2 -131*q^3*f1^2*f5*f10^7/f2 +256*q^4*f10^10/f1 -1024*q^5*f10^15/(f2*f5^5))

# %%
#N1 = 358459*(f2^2*f5^16/(f1*f10^8) -16*q*f2*f5^11/f10^3 +96*q^2*f1*f5^6*f10^2 -131*q^3*f1^2*f5*f10^7/f2 +256*q^4*f10^10/f1 -1024*q^5*f10^15/(f2*f5^5))

# %%
N1 = 358459*(f2^2*f5^16/(f1*f10^8) -16*A +96*B -131*C +256*D -1024*E)

# %%
#N2 = -10270191*q*f1^7*f10^2 -2875*q*f1^12*f10^3/(f2^5*f5) -5*56587027*q^2*f2^6*f10^4/f1 -186287434*q*f2^10*f5^2/f1^3 +976562500*q*f2^15*f5^3/(f1^8*f10)

# %%
N2 = -10270191*T2 -2875*T3 -5*56587027*T4 -186287434*T5 +976562500*T6

# %%
(N1+N2).O(7)
# Out:
# 358459 + 774625115*q + 7077040464*q^2 + 28004436110*q^3 + 73014343873*q^4 + 154165098863*q^5 + 295081997657*q^6 + O(q^7)

# %%
c10_15625n_1949_gen = 3125*(358459*F +774266656*q*G +7077040464*q^2*H +35855384771*q^3*I +151802153879*q^4*J +3142946984*q^5*K)
c10_15625n_1949_gen.O(11)
# Out:
# 1120184375 + 2420703484375*q + 22115751450000*q^2 + 87513862843750*q^3 + 228169824603125*q^4 + 481765933946875*q^5 + 922131242678125*q^6 + 1546484299509375*q^7 + 2419152579000000*q^8 + 3719221949721875*q^9 + 5294049583350000*q^10 + O(q^11)

# %% [markdown]
# ### 2

# %%
(q*f1^7*f10^2).O(11)
# Out:
# q - 7*q^2 + 14*q^3 + 7*q^4 - 49*q^5 + 21*q^6 + 35*q^7 + 41*q^8 - 49*q^9 - 133*q^10 + O(q^11)

# %%
(q*f2*f5^11/f10^3 -7*q^2*f1*f5^6*f10^2 +8*q^3*f1^2*f5*f10^7/f2 +16*q^4*f10^10/f1 -64*q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# q - 7*q^2 + 14*q^3 + 7*q^4 - 49*q^5 + 21*q^6 + 35*q^7 + 41*q^8 - 49*q^9 - 133*q^10 + O(q^11)

# %%
T2 = A -7*B +8*C +16*D -64*E
T2.O(11)
# Out:
# q - 7*q^2 + 14*q^3 + 7*q^4 - 49*q^5 + 21*q^6 + 35*q^7 + 41*q^8 - 49*q^9 - 133*q^10 + O(q^11)

# %% [markdown]
# ### 3

# %%
(q*f1^12*f10^3/(f2^5*f5)).O(11)
# Out:
# q - 12*q^2 + 59*q^3 - 148*q^4 + 191*q^5 - 139*q^6 + 220*q^7 - 429*q^8 + 76*q^9 + 587*q^10 + O(q^11)

# %%
(q*f2*f5^11/f10^3 -12*q^2*f1*f5^6*f10^2 +48*q^3*f1^2*f5*f10^7/f2 -64*q^4*f10^10/f1 +256*q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# q - 12*q^2 + 59*q^3 - 148*q^4 + 191*q^5 - 139*q^6 + 220*q^7 - 429*q^8 + 76*q^9 + 587*q^10 + O(q^11)

# %%
T3 = A -12*B +48*C -64*D +256*E
T3.O(11)
# Out:
# q - 12*q^2 + 59*q^3 - 148*q^4 + 191*q^5 - 139*q^6 + 220*q^7 - 429*q^8 + 76*q^9 + 587*q^10 + O(q^11)

# %% [markdown]
# ### 4

# %%
(q^2*f2^6*f10^4/f1).O(11)
# Out:
# q^2 + q^3 - 4*q^4 - 3*q^5 + 2*q^6 - 2*q^7 + 9*q^8 + 10*q^9 - 9*q^10 + O(q^11)

# %%
(q^2*f1*f5^6*f10^2 +2*q^3*f1^2*f5*f10^7/f2 +q^4*f10^10/f1 -4*q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# q^2 + q^3 - 4*q^4 - 3*q^5 + 2*q^6 - 2*q^7 + 9*q^8 + 10*q^9 - 9*q^10 + O(q^11)

# %%
T4 = B +2*C +D -4*E
T4.O(11)
# Out:
# q^2 + q^3 - 4*q^4 - 3*q^5 + 2*q^6 - 2*q^7 + 9*q^8 + 10*q^9 - 9*q^10 + O(q^11)

# %% [markdown]
# ### 5

# %%
(q*f2^10*f5^2/f1^3).O(11)
# Out:
# q + 3*q^2 - q^3 - 8*q^4 - 4*q^5 - 9*q^6 - 10*q^7 + 31*q^8 + 26*q^9 + 2*q^10 + O(q^11)

# %%
(q*f2*f5^11/f10^3 +3*q^2*f1*f5^6*f10^2 +3*q^3*f1^2*f5*f10^7/f2 +q^4*f10^10/f1 -4*q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# q + 3*q^2 - q^3 - 8*q^4 - 4*q^5 - 9*q^6 - 10*q^7 + 31*q^8 + 26*q^9 + 2*q^10 + O(q^11)

# %%
T5 = A +3*B +3*C +D -4*E
T5.O(11)
# Out:
# q + 3*q^2 - q^3 - 8*q^4 - 4*q^5 - 9*q^6 - 10*q^7 + 31*q^8 + 26*q^9 + 2*q^10 + O(q^11)

# %% [markdown]
# ### 6

# %%
(q*f2^15*f5^3/(f1^8*f10)).O(11)
# Out:
# q + 8*q^2 + 29*q^3 + 72*q^4 + 156*q^5 + 301*q^6 + 505*q^7 + 801*q^8 + 1226*q^9 + 1732*q^10 + O(q^11)

# %%
(q*f2*f5^11/f10^3 +8*q^2*f1*f5^6*f10^2 +38*q^3*f1^2*f5*f10^7/f2 +156*q^4*f10^10/f1 +q^5*f10^15/(f2*f5^5)).O(11)
# Out:
# q + 8*q^2 + 29*q^3 + 72*q^4 + 156*q^5 + 301*q^6 + 505*q^7 + 801*q^8 + 1226*q^9 + 1732*q^10 + O(q^11)

# %%
T6 = A +8*B +38*C +156*D +E
T6.O(11)
# Out:
# q + 8*q^2 + 29*q^3 + 72*q^4 + 156*q^5 + 301*q^6 + 505*q^7 + 801*q^8 + 1226*q^9 + 1732*q^10 + O(q^11)

# %%
(f1*f2^7*f5^2/f10).O(11)
# Out:
# 1 - q - 8*q^2 + 7*q^3 + 21*q^4 - 15*q^5 - 5*q^6 + 3*q^7 - 70*q^8 + 14*q^9 + 96*q^10 + O(q^11)

# %%
(f5^15/f10^6 + q*f1*f5^10/(f2*f10) -2*q*f2^2*f5^7 -7*q^2*f2^4*f10^6/f5 +3*q^3*f1^2*f10^10/f5^3).O(11)
# Out:
# 1 - q - 8*q^2 + 7*q^3 + 21*q^4 - 15*q^5 - 5*q^6 + 3*q^7 - 70*q^8 + 14*q^9 + 96*q^10 + O(q^11)

# %%
A = f2^2*f5^7
B = f2^4*f10^6/f5
C = f1^2*f10^10/f5^3
D = f2*f10^13/(f1*f5^4)
E = f2^3*f5^12/(f1*f10^5)

# %%
c10_125n_74 = [c10_list[125*i + 74] for i in range(0,11)]
c10_125n_74
# Out:
# [14375,
#  396000,
#  2148250,
#  6732000,
#  15407125,
#  30984375,
#  55548750,
#  88704250,
#  138230625,
#  205379125,
#  283080000]

# %%
(125*3053*q*A + 125*17301*q^2*B +125*59962*q^3*C + 5^7*500*q^4*D + 625*23*E).O(11)
# Out:
# 14375 + 396000*q + 2148250*q^2 + 6732000*q^3 + 15407125*q^4 + 30984375*q^5 + 55548750*q^6 + 88704250*q^7 + 138230625*q^8 + 205379125*q^9 + 283080000*q^10 + O(q^11)

# %%
E.O(21)
# Out:
# 1 + q - q^2 - q^4 - 14*q^5 - 11*q^6 + 11*q^7 - q^8 + 12*q^9 + 84*q^10 + 48*q^11 - 48*q^12 + 13*q^13 - 59*q^14 - 276*q^15 - 100*q^16 + 101*q^17 - 71*q^18 + 147*q^19 + 524*q^20 + O(q^21)

# %%
(f1^15/f2^6 + q*f1^12*f10^3/(f2^5*f5)).O(11)
# Out:
# 1 - 14*q + 84*q^2 - 276*q^3 + 524*q^4 - 577*q^5 + 534*q^6 - 1028*q^7 + 1491*q^8 - 20*q^9 - 1780*q^10 + O(q^11)

# %%
F = f2^2*f5^16/(f1*f10^8)
G = f2*f5^11/f10^3
H = f1*f5^6*f10^2
I = f1^2*f5*f10^7/f2
J = f10^10/f1
K = f10^15/(f2*f5^5)

# %%
(F -15*q*G + 84*q^2*H -208*q^3*I +192*q^4*J -768*q^5*K).O(11)
# Out:
# 1 - 14*q + 84*q^2 - 276*q^3 + 524*q^4 - 577*q^5 + 534*q^6 - 1028*q^7 + 1491*q^8 - 20*q^9 - 1780*q^10 + O(q^11)

# %%
c10_625n_74 = [c10_list[625*i + 74] for i in range(0,8)]
c10_25n_neq1 = [c10_list[25*i - 1] for i in range(0,8)]

[c10_625n_74[i] - 5^7*c10_25n_neq1[i] for i in range(1,8)]
# Out:
# [-265625, 1830000, -2862500, 4560000, -11158750, 10336875, -15540000]

# %%
(125*(115*(F -15*q*G +84*q^2*H -208*q^3*I +192*q^4*J -768*q^5*K) -515*q*G +1545*q^2*H +2060*q^3*I -288*q^2*H +3*288*q^3*I +4*288*q^4*J -16*288*q^5*K +3723*q^2*H +3723*q^3*I +6658*q^3*I +6658*q^4*J -4*6658*q^5*K)).O(8)
# Out:
# 14375 - 265625*q + 1830000*q^2 - 2862500*q^3 + 4560000*q^4 - 11158750*q^5 + 10336875*q^6 - 15540000*q^7 + O(q^8)

# %%
125*(115*F -2240*q*G +14640*q^2*H -10615*q^3*I +29890*q^4*J -119560*q^5*K).O(11)
# Out:
# 14375 - 265625*q + 1830000*q^2 - 2862500*q^3 + 4560000*q^4 - 11158750*q^5 + 10336875*q^6 - 15540000*q^7 + 27678125*q^8 + 6420000*q^9 - 35081875*q^10 + O(q^11)

# %%
c10_625n_74_gen= 625*(23*F -448*q*G +2928*q^2*H -2123*q^3*I +5978*q^4*J -23912*q^5*K)
c10_625n_74_gen.O(11)
# Out:
# 14375 - 265625*q + 1830000*q^2 - 2862500*q^3 + 4560000*q^4 - 11158750*q^5 + 10336875*q^6 - 15540000*q^7 + 27678125*q^8 + 6420000*q^9 - 35081875*q^10 + O(q^11)

# %%
(125*(115*(F -15*q*G +84*q^2*H -208*q^3*I +192*q^4*J -768*q^5*K) -515*q*f1^3*f2^2*f5^4 -288*q^2*f1^4*f2*f10^5/f5 +3723*q^2*f2^3*f5^3*f10^3 +6658*q^3*f1*f2^2*f10^8/f5^2)).O(8)
# Out:
# 14375 - 265625*q + 1830000*q^2 - 2862500*q^3 + 4560000*q^4 - 11158750*q^5 + 10336875*q^6 - 15540000*q^7 + O(q^8)

# %%
(-515*q*f1^3*f2^2*f5^4).O(11)
# Out:
# -515*q + 1545*q^2 + 1030*q^3 - 5665*q^4 + 515*q^5 + 5665*q^6 - 3605*q^7 + 1545*q^8 + 14935*q^9 - 5665*q^10 + O(q^11)

# %%
(-515*q*G +1545*q^2*H +2060*q^3*I).O(11)
# Out:
# -515*q + 1545*q^2 + 1030*q^3 - 5665*q^4 + 515*q^5 + 5665*q^6 - 3605*q^7 + 1545*q^8 + 14935*q^9 - 5665*q^10 + O(q^11)

# %%
(-288*q^2*f1^4*f2*f10^5/f5).O(11)
# Out:
# -288*q^2 + 1152*q^3 - 288*q^4 - 3456*q^5 + 2304*q^6 + 2016*q^7 + 3168*q^8 - 1440*q^9 - 10368*q^10 + O(q^11)

# %%
(-288*q^2*H +3*288*q^3*I +4*288*q^4*J -16*288*q^5*K).O(11)
# Out:
# -288*q^2 + 1152*q^3 - 288*q^4 - 3456*q^5 + 2304*q^6 + 2016*q^7 + 3168*q^8 - 1440*q^9 - 10368*q^10 + O(q^11)

# %%
(6658*q^3*f1*f2^2*f10^8/f5^2).O(11)
# Out:
# 6658*q^3 - 6658*q^4 - 19974*q^5 + 13316*q^6 + 6658*q^7 + 26632*q^8 + 6658*q^9 - 59922*q^10 + O(q^11)

# %%
(6658*q^3*I +6658*q^4*J -4*6658*q^5*K).O(11)
# Out:
# 6658*q^3 - 6658*q^4 - 19974*q^5 + 13316*q^6 + 6658*q^7 + 26632*q^8 + 6658*q^9 - 59922*q^10 + O(q^11)

# %%
c10_3125n_1949_gen = 3125*(358459*f1*f2^7*f5^2/f10 +10270191*q*f2^2*f5^7 -2875*q*f1*f5^10/(f2*f10) +56587027*q^2*f2^4*f10^6/f5 +186287434*q^3*f1^2*f10^10/f5^3 +976562500*q^4*f2*f10^13/(f1*f5^4))
c10_3125n_1949_gen.O(11)
# Out:
# 1120184375 + 30965178125*q + 167881968750*q^2 + 525800828125*q^3 + 1203656368750*q^4 + 2420703484375*q^5 + 4339560671875*q^6 + 6929948734375*q^7 + 10799849390625*q^8 + 16045450115625*q^9 + 22115751450000*q^10 + O(q^11)

# %%
c10_125n_74_gen = 125*(115*f1*f2^7*f5^2/f10 +3283*q*f2^2*f5^7 +18106*q^2*f2^4*f10^6/f5 +59617*q^3*f1^2*f10^10/f5^3 +312500*q^4*f2*f10^13/(f1*f5^4))
c10_125n_74_gen.O(11)
# Out:
# 14375 + 396000*q + 2148250*q^2 + 6732000*q^3 + 15407125*q^4 + 30984375*q^5 + 55548750*q^6 + 88704250*q^7 + 138230625*q^8 + 205379125*q^9 + 283080000*q^10 + O(q^11)

# %%
c10_625n_74 = [c10_list[625*i + 74] for i in range(0,8)]
c10_625n_74
# Out:
# [14375,
#  30984375,
#  283080000,
#  1120184375,
#  2920575625,
#  6166575625,
#  11803305625,
#  19795006875]

# %%
c10_625n_74_gen = 625*(23*f2^2*f5^16/(f1*f10^8) +49552*q*f2*f5^11/f10^3 +452928*q^2*f1*f5^6*f10^2 +2294752*q^3*f1^2*f5*f10^7/f2 +9715353*q^4*f10^10/f1 +201088*q^5*f10^15/(f2*f5^5))
c10_625n_74_gen.O(8)
# Out:
# 14375 + 30984375*q + 283080000*q^2 + 1120184375*q^3 + 2920575625*q^4 + 6166575625*q^5 + 11803305625*q^6 + 19795006875*q^7 + O(q^8)

# %%
c10_25n_24 = [c10_list[25*i + 24] for i in range(0,8)]
c10_25n_24
# Out:
# [400, 3600, 14375, 37325, 79075, 150950, 253575, 396000]

# %%
c10_25n_24_gen = 25*(16*f2*f5^11/f10^3 +144*q*f1*f5^6*f10^2 +735*q^2*f1^2*f5*f10^7/f2 +3107*q^3*f10^10/f1 +72*q^4*f10^15/(f2*f5^5))
c10_25n_24_gen.O(8)
# Out:
# 400 + 3600*q + 14375*q^2 + 37325*q^3 + 79075*q^4 + 150950*q^5 + 253575*q^6 + 396000*q^7 + O(q^8)

# %%
(9*c10_625n_74_gen -9*5^7*q*c10_25n_24_gen +25*2989*q*c10_25n_24_gen -5^9*2989*q^4*c10).O(11)
# Out:
# 129375 + 27499375*q + 285480000*q^2 + 1048409375*q^3 - 3007740000*q^4 - 29440000*q^5 - 303010625*q^6 + 1294860000*q^7 + 650750000*q^8 + 4720620000*q^9 + 315689375*q^10 + O(q^11)

# %%
625*(207*f5^16*f2^2/(f1*f10^8) +43792*q*f2*f5^11/f10^3 +456768*q^2*f1*f5^6*f10^2 +2177808*q^3*f1^2*f5*f10^7/f2).O(11)
# Out:
# 129375 + 27499375*q + 285480000*q^2 + 1048409375*q^3 - 3007740000*q^4 - 29440000*q^5 - 303010625*q^6 + 1294860000*q^7 + 650750000*q^8 + 4720620000*q^9 + 315689375*q^10 + O(q^11)

# %%
c_5n_4_gen = 5*f2^10*f5^5/f1^6

# %%
(9*c10_3125n_1949_gen -628400*c10_125n_74_gen -5^9*2989*q*c_5n_4_gen).O(11)
# Out:
# 1048409375 + 650750000*q - 14159300000*q^2 + 5597950000*q^3 + 41870750000*q^4 - 19406140625*q^5 - 24880250000*q^6 + 1782050000*q^7 - 86115000000*q^8 + 24346000000*q^9 + 137884800000*q^10 + O(q^11)

# %%
625*(207*f1^16*f10^2/(f2^8*f5) -43792*f1^11*f10/f2^3 -456768*f1^6*f2^2*f5 +2177808*f1*f2^7*f5^2/f10).O(11)
# Out:
# 1048409375 + 650750000*q - 14159300000*q^2 + 5597950000*q^3 + 41870750000*q^4 - 19406140625*q^5 - 24880250000*q^6 + 1782050000*q^7 - 86115000000*q^8 + 24346000000*q^9 + 137884800000*q^10 + O(q^11)

# %%
#(207*f1^16*f10^2/(f2^8*f5) -43792*f1^11*f10/f2^3 -456768*f1^6*f2^2*f5).O(11)

# %%
#(-500353*f1*f2^7*f5^2/f10 + 5*543731*q*f2^2*f5^7 +5*543731*q^2*f1*f2*f5^2*f10^5 -5*2390779*q^2*f2^4*f10^6/f5 +125*42964*q^3*f1^2*f10^10/f5^3 +625*207*q^4*f1^4*f10^14/(f2^4*f5^5)).O(11)

# %%
3125*(335491*f5^15/f10^6 +309616*q*f1*f5^10/(f2*f10) -101376*q*A -4221360*q^2*B +1588592*q^3*C).O(11)
# Out:
# 1048409375 + 650750000*q - 14159300000*q^2 + 5597950000*q^3 + 41870750000*q^4 - 19406140625*q^5 - 24880250000*q^6 + 1782050000*q^7 - 86115000000*q^8 + 24346000000*q^9 + 137884800000*q^10 + O(q^11)

# %%
(9*c10_625n_74_gen - 25*25136*q*c10_25n_24_gen).O(11)
# Out:
# 129375 + 27499375*q + 285480000*q^2 + 1048409375*q^3 + 2830150625*q^4 + 5808450625*q^5 + 11372770625*q^6 + 18808531875*q^7 + 29840203125*q^8 + 45585854375*q^9 + 64532486250*q^10 + O(q^11)

# %%
625*(207*F +43792*q*G +456768*q^2*H +2177808*q^3*I +9340625*q^4*J).O(11)
# Out:
# 129375 + 27499375*q + 285480000*q^2 + 1048409375*q^3 + 2830150625*q^4 + 5808450625*q^5 + 11372770625*q^6 + 18808531875*q^7 + 29840203125*q^8 + 45585854375*q^9 + 64532486250*q^10 + O(q^11)

# %%
(25136*c10_15625n_1949_gen - 5*392868373*c10_625n_74_gen).O(11)
# Out:
# -80459859375 - 17102190109375*q - 164366697000000*q^2 - 676607890859375*q^3 - 1732258861890625*q^4 - 3594148187390625*q^5 - 7036468620140625*q^6 - 11731370057671875*q^7 - 18376522375703125*q^8 - 28153599523234375*q^9 - 39933361026156250*q^10 + O(q^11)

# %%
3125*(-25747155*F -5446953680*q*G -52597343040*q^2*H -274533074640*q^3*I -1155986328125*q^4*J).O(11)
# Out:
# -80459859375 - 17102190109375*q - 164366697000000*q^2 - 676607890859375*q^3 - 1732258861890625*q^4 - 3594148187390625*q^5 - 7036468620140625*q^6 - 11731370057671875*q^7 - 18376522375703125*q^8 - 28153599523234375*q^9 - 39933361026156250*q^10 + O(q^11)

# %%
#(9*3125*c10_15625n_1949_gen - 125*392868373*q*c10_25n_24_gen).O(11)

# %%
#3125*(3226131*F +682505936*q*G +7120318464*q^2*H +33940208784*q^3*I +145577350000*q^4*J).O(11)

# %%
#9*35855384771 - 735*392868373
#9*151802153879 - 3107*392868373
#52597343040*2177808 - 456768*274533074640
#7120318464*2177808 - 456768*33940208784
#10851008985907200/gcd(3885227596800,10851008985907200), 3885227596800/gcd(3885227596800,10851008985907200)

# %%
#9*52597343040 +25136*7120318464
#gcd(gcd(179449700998464, 9*456768), 25136*456768)

#179449700998464/456768

# %%
#358459-2875
#10270191 -2*358459
#56587027 -7*358459
#186287434 +3*358459
#15625*3 +1949
#358459 -774266656 
#-773908197-7077040464
#5*773908197 -5*358459
#35855384771 -7850948661
#5*7850948661 +3867748690
#25*358459 -5*3867748690
# -125*358459
#5*3142946984 -19329781975
#5*19329781975 +25*3142946984 -125*358459
5^7
# Out:
# 78125

# %%
#c10_78125n_48824 = [c10_list[78125*i + 48824] for i in range(0,1)]
#c10_78125n_48824
c10_15625n_1949_gen.O(11)
# Out:
# 1120184375 + 2420703484375*q + 22115751450000*q^2 + 87513862843750*q^3 + 228169824603125*q^4 + 481765933946875*q^5 + 922131242678125*q^6 + 1546484299509375*q^7 + 2419152579000000*q^8 + 3719221949721875*q^9 + 5294049583350000*q^10 + O(q^11)

# %%
P = f5^15/f10^6
R = f1*f5^10/(f2*f10)
c10_78125n_48824_gen = 15625*(5600887222*P +5556079847*q*R +149269685209*q*A +844965400737*q^2*B +2927544257138*q^3*C +15258789062500*q^4*D)
c10_78125n_48824_gen.O(11)
# Out:
# 87513862843750 + 2419152579000000*q + 13115770638906250*q^2 + 41078201355000000*q^3 + 94035669772328125*q^4 + 189117467057343750*q^5 + 339028182866718750*q^6 + 541402250493906250*q^7 + 843738158276015625*q^8 + 1253550787825328125*q^9 + 1727793011508000000*q^10 + O(q^11)
